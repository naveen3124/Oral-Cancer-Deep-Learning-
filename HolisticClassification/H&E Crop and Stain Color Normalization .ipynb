# %%
#taken from the several iciar 2018 implementations

import argparse
import numpy as np
import cv2
from scipy import ndimage
import os
from os.path import basename, join, exists
from os import makedirs
#from threaded_generator import threaded_generator
from time import time
import sys
np.random.seed(13)

PATCH_SIZES = [224, 224]
SCALES = [0.5]

DEFAULT_INPUT_DIR = "data/train"
DEFAULT_PREPROCESSED_ROOT = "data/preprocessed/train"

PATCHES_PER_IMAGE = 20
AUGMENTATIONS_PER_IMAGE = 50
COLOR_LO = 0.7
COLOR_HI = 1.3
BATCH_SIZE = 16     # decrease if necessary

NUM_CACHED = 160

# %%
def normalize_staining(img):
   
    Io = 240
    beta = 0.15
    alpha = 1
    HERef = np.array([[0.5626, 0.2159],
                      [0.7201, 0.8012],
                      [0.4062, 0.5581]])
    maxCRef = np.array([1.9705, 1.0308])

    h, w, c = img.shape
    img = img.reshape(h * w, c)
    OD = -np.log((img.astype("uint16") + 1) / Io)
    ODhat = OD[(OD >= beta).all(axis=1)]
    W, V = np.linalg.eig(np.cov(ODhat, rowvar=False))

    Vec = -V.T[:2][::-1].T  
    That = np.dot(ODhat, Vec)
    phi = np.arctan2(That[:, 1], That[:, 0])
    minPhi = np.percentile(phi, alpha)
    maxPhi = np.percentile(phi, 100 - alpha)
    vMin = np.dot(Vec, np.array([np.cos(minPhi), np.sin(minPhi)]))
    vMax = np.dot(Vec, np.array([np.cos(maxPhi), np.sin(maxPhi)]))
    if vMin[0] > vMax[0]:
        HE = np.array([vMin, vMax])
    else:
        HE = np.array([vMax, vMin])

    HE = HE.T
    Y = OD.reshape(h * w, c).T

    C = np.linalg.lstsq(HE, Y)
    maxC = np.percentile(C[0], 99, axis=1)

    C = C[0] / maxC[:, None]
    C = C * maxCRef[:, None]
    Inorm = Io * np.exp(-np.dot(HERef, C))
    Inorm = Inorm.T.reshape(h, w, c).clip(0, 255).astype("uint8")

    return Inorm


def hematoxylin_eosin_aug(img, low=0.7, high=1.3, seed=None):
    D = np.array([[1.88, -0.07, -0.60],
                  [-1.02, 1.13, -0.48],
                  [-0.55, -0.13, 1.57]])
    M = np.array([[0.65, 0.70, 0.29],
                  [0.07, 0.99, 0.11],
                  [0.27, 0.57, 0.78]])
    Io = 240

    h, w, c = img.shape
    OD = -np.log10((img.astype("uint16") + 1) / Io)
    C = np.dot(D, OD.reshape(h * w, c).T).T
    r = np.ones(3)
    r[:2] = np.random.RandomState(seed).uniform(low=low, high=high, size=2)
    img_aug = np.dot(C, M) * r

    img_aug = Io * np.exp(-img_aug * np.log(10)) - 1
    img_aug = img_aug.reshape(h, w, c).clip(0, 255).astype("uint8")
    return img_aug

def zoom_aug(img, zoom_var, seed=None):
    scale = np.random.RandomState(seed).uniform(low=1 / zoom_var, high=zoom_var)
    resized_img = cv2.resize(img, None, fx=scale, fy=scale, interpolation=cv2.INTER_CUBIC)
    return resized_img

def get_crops(img, size, n, seed=None):
    h, w, c = img.shape
    assert all([size < h, size < w])
    crops = []
    for _ in range(n):
        top = np.random.randint(low=0, high=h - size + 1)
        left = np.random.randint(low=0, high=w - size + 1)
        crop = img[top: top + size, left: left + size].copy()
        crop = np.rot90(crop, np.random.randint(low=0, high=4))
        if np.random.random() > 0.5:
            crop = np.flipud(crop)
        if np.random.random() > 0.5:
            crop = np.fliplr(crop)
        crops.append(crop)

    crops = np.stack(crops)
    assert crops.shape == (n, size, size, c)
    return crops


def get_crops_free(img, size, n, seed=None):
    h, w, c = img.shape
    assert all([size < h, size < w])
    d = int(np.ceil(size / np.sqrt(2)))
    crops = []
    for _ in range(n):
        center_y = np.random.randint(low=0, high=h - size + 1) + size // 2
        center_x = np.random.randint(low=0, high=w - size + 1) + size // 2
        m = min(center_y, center_x, h - center_y, w - center_x)
        if m < d:
            max_angle = np.pi / 4 - np.arccos(m / d)
            top = center_y - m
            left = center_x - m
            precrop = img[top: top + 2 * m, left: left + 2 * m]
        else:
            max_angle = np.pi / 4
            top = center_y - d
            left = center_x - d
            precrop = img[top: top + 2 * d, left: left + 2 * d]

        precrop = np.rot90(precrop, np.random.randint(low=0, high=4))
        angle = np.random.uniform(low=-max_angle, high=max_angle)
        precrop = ndimage.rotate(precrop, angle * 180 / np.pi, reshape=False)

        precrop_h, precrop_w, _ = precrop.shape
        top = (precrop_h - size) // 2
        left = (precrop_w - size) // 2
        crop = precrop[top: top + size, left: left + size]

        if np.random.random() > 0.5:
            crop = np.flipud(crop)
        if np.random.random() > 0.5:
            crop = np.fliplr(crop)
        crops.append(crop)

    crops = np.stack(crops)
    assert crops.shape == (n, size, size, c)
    return crops


def norm_pool(features, p=3):
    return np.power(np.power(features, p).mean(axis=0), 1/p)


def encode(crops, model):
    features = model.predict(crops)
    pooled_features = norm_pool(features)
    return pooled_features


def process_image(image_file):
    img = cv2.imread(image_file)
    if SCALE != 1:
        img = cv2.resize(img, None, fx=SCALE, fy=SCALE, interpolation=cv2.INTER_CUBIC)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_norm = normalize_staining(img)

    for _ in range(AUGMENTATIONS_PER_IMAGE):
        img_aug = hematoxylin_eosin_aug(img_norm, low=COLOR_LO, high=COLOR_HI)
        single_image_crops = get_crops(img_aug, PATCH_SZ, PATCHES_PER_IMAGE)
        yield single_image_crops


def crops_gen(file_list):
    for i, (image_file, output_file) in enumerate(file_list):
        print("Crops generator:", i + 1)
        for crops in process_image(image_file):
            yield crops, output_file


def features_gen(crops_and_output_file, model):
    print("features gen");
    ts = time()
    current_file = None
    pooled_features = []
    i = 0
    for j, (crops, output_file) in enumerate(crops_and_output_file):
        print("cropping",j)
        if current_file is None:
            current_file = output_file
        features = encode(crops, model)
        if output_file == current_file:
            pooled_features.append(features)
        else:
            np.save(current_file, np.stack(pooled_features))
            pooled_features = [features]
            current_file = output_file
            average_time = int((time() - ts) / (i + 1))
            print("Feature generator: {}, {} sec/image.".format(i + 1, average_time))
            i += 1
    if len(pooled_features) > 0:
        np.save(current_file, np.stack(pooled_features))

# %%
DATASET_PATH = 'E:\Projects\HolisticClassification\TempDataset' # the dataset file or root folder path.
TEST_DATASET_PATH = 'E:\Projects\HolisticClassification\TempDataset\Test'

BATCH_SIZE = 4
MODE = 'folder' # or 'file', if you choose a plain text file (see above).
from PIL import Image
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
import time 

import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
#define 
def read_images_convert_to_jpeg(dataset_path = DATASET_PATH, mode = MODE, batch_size = BATCH_SIZE):
    imagepaths, labels = list(), list()
    if mode == 'folder':
        label = 0
        classes = [f.path for f in os.scandir(dataset_path) if f.is_dir() ] 
        for c in classes:
            c_dir = os.path.join(dataset_path, c)
            walk = os.walk(c_dir).__next__()
            for sample in walk[2]:
                if sample.endswith('.BMP') or sample.endswith('.bmp'):
                    imagepaths.append(os.path.join(c_dir, sample))
                    labels.append(label)
            label += 1
    else:
        raise Exception("Unknown mode.")
    for image_loc in imagepaths:
        new_img = Image.open(image_loc)
        save_loc = os.path.splitext(image_loc)[0] + ".jpeg"
        print(save_loc)
        new_img.save( save_loc, 'jpeg')

# %%
#read_images_convert_to_jpeg()

# %%
import numpy as np

import tensorflow as tf
class ResNet:
    __name__ = "ResNet"

    def __init__(self, batch_size=16):
        self.model = tf.contrib.keras.applications.resnet50.ResNet50(include_top=True, weights='imagenet', pooling="avg")
        self.batch_size = batch_size
        self.data_format =  tf.keras.backend.image_data_format()

    def predict(self, x):
        if self.data_format == "channels_first":
            x = x.transpose(0, 3, 1, 2)
        x = tf.contrib.keras.applications.resnet50.preprocess_input(x.astype(tf.keras.backend.floatx()))
        return self.model.predict(x, batch_size=16)

# %%
def threaded_generator(generator, num_cached=50):
    """Implements threaded generator to produce batches in background thread.
    # Arguments
        generator: an object exposing generator interface.
    # Yields
        Objects generated by generator.
    """
    from queue import Queue

    qu = Queue(maxsize=num_cached)
    sentinel = object()  # guaranteed unique reference

    # define producer (putting items into queue)
    def producer():
        for item in generator:
            qu.put(item)
        qu.put(sentinel)

    # start producer (in a background thread)
    import threading
    thread = threading.Thread(target=producer)
    thread.daemon = True
    thread.start()
    item = qu.get()
    while item is not sentinel:
        yield item
        qu.task_done()
        item = qu.get()

# %%
import os
from os.path import basename, join, exists
DATASET_PATH = 'E:\Projects\HolisticClassification\TempDataset' # the dataset file or root folder path.


NUM_CACHED = 160
NN_MODELS = [ResNet]
for SCALE in SCALES:
        print("SCALE:", SCALE)
        for NN_MODEL in NN_MODELS:
            print("NN_MODEL:", NN_MODEL.__name__)
            for PATCH_SZ in PATCH_SIZES:
                print("PATCH_SZ:", PATCH_SZ)
                model = NN_MODEL(batch_size=BATCH_SIZE)
                imagepaths, labels = list(), list()
                label = 0
                classes = [f.path for f in os.scandir(DATASET_PATH) if f.is_dir() ] 
                for c in classes:
                    c_dir = os.path.join(DATASET_PATH, c)
                    walk = os.walk(c_dir).__next__()
                    for sample in walk[2]:
                        if sample.endswith('.jpeg') or sample.endswith('.jpg'):
                            imagepaths.append(os.path.join(c_dir, sample))
                            labels.append(label)
                            label += 1
                output_files = [join(DATASET_PATH, basename(f).replace("jpeg", "npy")) for f in imagepaths]
                file_list = zip(imagepaths, output_files)

                crops_and_output_file = crops_gen(file_list)
                #crops_and_output_file_ = threaded_generator(crops_and_output_file, num_cached=NUM_CACHED)
                features_gen(crops_and_output_file, model)
# Out:
# SCALE: 0.5
# NN_MODEL: ResNet
# PATCH_SZ: 224
# features gen
# Crops generator: 1
# E:\Anaconda3\envs\tfdeeplearning\lib\site-packages\ipykernel_launcher.py:32: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
# cropping 0
# cropping 1
# cropping 2
# cropping 3
# cropping 4
# cropping 5
# cropping 6
# cropping 7
# cropping 8
# cropping 9
# cropping 10
# cropping 11
# cropping 12
# cropping 13
# cropping 14
# cropping 15
# cropping 16
# cropping 17
# cropping 18
# cropping 19
# cropping 20
# cropping 21
# cropping 22
# cropping 23
# cropping 24
# cropping 25
# cropping 26
# cropping 27
# cropping 28
# cropping 29
# cropping 30
# cropping 31
# cropping 32
# cropping 33
# cropping 34
# cropping 35
# cropping 36
# cropping 37
# cropping 38
# cropping 39
# cropping 40
# cropping 41
# cropping 42
# cropping 43
# cropping 44
# cropping 45
# cropping 46
# cropping 47
# cropping 48
# cropping 49
# Crops generator: 2
# cropping 50
# Feature generator: 1, 395 sec/image.
# cropping 51
# cropping 52
# cropping 53
# cropping 54
# cropping 55
# cropping 56
# cropping 57
# cropping 58
# cropping 59
# cropping 60
# cropping 61
# cropping 62
# cropping 63
# cropping 64
# cropping 65
# cropping 66
# cropping 67
# cropping 68
# cropping 69
# cropping 70
# cropping 71
# cropping 72
# cropping 73
# cropping 74
# cropping 75
# cropping 76
# cropping 77
# cropping 78
# cropping 79
# cropping 80
# cropping 81
# cropping 82
# cropping 83
# cropping 84
# cropping 85
# cropping 86
# cropping 87
# cropping 88
# cropping 89
# cropping 90
# cropping 91
# cropping 92
# cropping 93
# cropping 94
# cropping 95
# cropping 96
# cropping 97
# cropping 98
# cropping 99
# Crops generator: 3
# cropping 100
# Feature generator: 2, 403 sec/image.
# cropping 101
# cropping 102
# cropping 103
# cropping 104
# cropping 105
# cropping 106
# cropping 107
# cropping 108
# cropping 109
# cropping 110
# cropping 111
# cropping 112
# cropping 113
# cropping 114
# cropping 115
# cropping 116
# cropping 117
# cropping 118
# cropping 119
# cropping 120
# cropping 121
# cropping 122
# cropping 123
# cropping 124
# cropping 125
# cropping 126
# cropping 127
# cropping 128
# cropping 129
# cropping 130
# cropping 131
# cropping 132
# cropping 133
# cropping 134
# cropping 135
# cropping 136
# cropping 137
# cropping 138
# cropping 139
# cropping 140
# cropping 141
# cropping 142
# cropping 143
# cropping 144
# cropping 145
# cropping 146
# cropping 147
# cropping 148
# cropping 149
# Crops generator: 4
# cropping 150
# Feature generator: 3, 410 sec/image.
# cropping 151
# cropping 152
# cropping 153
# cropping 154
# cropping 155
# cropping 156
# cropping 157
# cropping 158
# cropping 159
# cropping 160
# cropping 161
# cropping 162
# cropping 163
# cropping 164
# cropping 165
# cropping 166
# cropping 167
# cropping 168
# cropping 169
# cropping 170
# cropping 171
# cropping 172
# cropping 173
# cropping 174
# cropping 175
# cropping 176
# cropping 177
# cropping 178
# cropping 179
# cropping 180
# cropping 181
# cropping 182
# cropping 183
# cropping 184
# cropping 185
# cropping 186
# cropping 187
# cropping 188
# cropping 189
# cropping 190
# cropping 191
# cropping 192
# cropping 193
# cropping 194
# cropping 195
# cropping 196
# cropping 197
# cropping 198
# cropping 199
# Crops generator: 5
# cropping 200
# Feature generator: 4, 410 sec/image.
# cropping 201
# cropping 202
# cropping 203
# cropping 204
# cropping 205
# cropping 206
# cropping 207
# cropping 208
# cropping 209
# cropping 210
# cropping 211
# cropping 212
# cropping 213
# cropping 214
# cropping 215
# cropping 216
# cropping 217
# cropping 218
# cropping 219
# cropping 220
# cropping 221
# cropping 222
# cropping 223
# cropping 224
# cropping 225
# cropping 226
# cropping 227
# cropping 228
# cropping 229
# cropping 230
# cropping 231
# cropping 232
# cropping 233
# cropping 234
# cropping 235
# cropping 236
# cropping 237
# cropping 238
# cropping 239
# cropping 240
# cropping 241
# cropping 242
# cropping 243
# cropping 244
# cropping 245
# cropping 246
# cropping 247
# cropping 248
# cropping 249
# Crops generator: 6
# cropping 250
# Feature generator: 5, 409 sec/image.
# cropping 251
# cropping 252
# cropping 253
# cropping 254
# cropping 255
# cropping 256
# cropping 257
# cropping 258
# cropping 259
# cropping 260
# cropping 261
# cropping 262
# cropping 263
# cropping 264
# cropping 265
# cropping 266
# cropping 267
# cropping 268
# cropping 269
# cropping 270
# cropping 271
# cropping 272
# cropping 273
# cropping 274
# cropping 275
# cropping 276
# cropping 277
# cropping 278
# cropping 279
# cropping 280
# cropping 281
# cropping 282
# cropping 283
# cropping 284
# cropping 285
# cropping 286
# cropping 287
# cropping 288
# cropping 289
# cropping 290
# cropping 291
# cropping 292
# cropping 293
# cropping 294
# cropping 295
# cropping 296
# cropping 297
# cropping 298
# cropping 299
# Crops generator: 7
# cropping 300
# Feature generator: 6, 407 sec/image.
# cropping 301
# cropping 302
# cropping 303
# cropping 304
# cropping 305
# cropping 306
# cropping 307
# cropping 308
# cropping 309
# cropping 310
# cropping 311
# cropping 312
# cropping 313
# cropping 314
# cropping 315
# cropping 316
# cropping 317
# cropping 318
# cropping 319
# cropping 320
# cropping 321
# cropping 322
# cropping 323
# cropping 324
# cropping 325
# cropping 326
# cropping 327
# cropping 328
# cropping 329
# cropping 330
# cropping 331
# cropping 332
# cropping 333
# cropping 334
# cropping 335
# cropping 336
# cropping 337
# cropping 338
# cropping 339
# cropping 340
# cropping 341
# cropping 342
# cropping 343
# cropping 344
# cropping 345
# cropping 346
# cropping 347
# cropping 348
# cropping 349
# Crops generator: 8
# cropping 350
# Feature generator: 7, 404 sec/image.
# cropping 351
# cropping 352
# cropping 353
# cropping 354
# cropping 355
# cropping 356
# cropping 357
# cropping 358
# cropping 359
# cropping 360
# cropping 361
# cropping 362
# cropping 363
# cropping 364
# cropping 365
# cropping 366
# cropping 367
# cropping 368
# cropping 369
# cropping 370
# cropping 371
# cropping 372
# cropping 373
# cropping 374
# cropping 375
# cropping 376
# cropping 377
# cropping 378
# cropping 379
# cropping 380
# cropping 381
# cropping 382
# cropping 383
# cropping 384
# cropping 385
# cropping 386
# cropping 387
# cropping 388
# cropping 389
# cropping 390
# cropping 391
# cropping 392
# cropping 393
# cropping 394
# cropping 395
# cropping 396
# cropping 397
# cropping 398
# cropping 399
# Crops generator: 9
# cropping 400
# Feature generator: 8, 402 sec/image.
# cropping 401
# cropping 402
# cropping 403
# cropping 404
# cropping 405
# cropping 406
# cropping 407
# cropping 408
# cropping 409
# cropping 410
# cropping 411
# cropping 412
# cropping 413
# cropping 414
# cropping 415
# cropping 416
# cropping 417
# cropping 418
# cropping 419
# cropping 420
# cropping 421
# cropping 422
# cropping 423
# cropping 424
# cropping 425
# cropping 426
# cropping 427
# cropping 428
# cropping 429
# cropping 430
# cropping 431
# cropping 432
# cropping 433
# cropping 434
# cropping 435
# cropping 436
# cropping 437
# cropping 438
# cropping 439
# cropping 440
# cropping 441
# cropping 442
# cropping 443
# cropping 444
# cropping 445
# cropping 446
# cropping 447
# cropping 448
# cropping 449
# Crops generator: 10
# cropping 450
# Feature generator: 9, 401 sec/image.
# cropping 451
# cropping 452
# cropping 453
# cropping 454
# cropping 455
# cropping 456
# cropping 457
# cropping 458
# cropping 459
# cropping 460
# cropping 461
# cropping 462
# cropping 463
# cropping 464
# cropping 465
# cropping 466
# cropping 467
# cropping 468
# cropping 469
# cropping 470
# cropping 471
# cropping 472
# cropping 473
# cropping 474
# cropping 475
# cropping 476
# cropping 477
# cropping 478
# cropping 479
# cropping 480
# cropping 481
# cropping 482
# cropping 483
# cropping 484
# cropping 485
# cropping 486
# cropping 487
# cropping 488
# cropping 489
# cropping 490
# cropping 491
# cropping 492
# cropping 493
# cropping 494
# cropping 495
# cropping 496
# cropping 497
# cropping 498
# cropping 499
# Crops generator: 11
# cropping 500
# Feature generator: 10, 400 sec/image.
# cropping 501
# cropping 502
# cropping 503
# cropping 504
# cropping 505
# cropping 506
# cropping 507
# cropping 508
# cropping 509
# cropping 510
# cropping 511
# cropping 512
# cropping 513
# cropping 514
# cropping 515
# cropping 516
# cropping 517
# cropping 518
# cropping 519
# cropping 520
# cropping 521
# cropping 522
# cropping 523
# cropping 524
# cropping 525
# cropping 526
# cropping 527
# cropping 528
# cropping 529
# cropping 530
# cropping 531
# cropping 532
# cropping 533
# cropping 534
# cropping 535
# cropping 536
# cropping 537
# cropping 538
# cropping 539
# cropping 540
# cropping 541
# cropping 542
# cropping 543
# cropping 544
# cropping 545
# cropping 546
# cropping 547
# cropping 548
# cropping 549
# Crops generator: 12
# cropping 550
# Feature generator: 11, 399 sec/image.
# cropping 551
# cropping 552
# cropping 553
# cropping 554
# cropping 555
# cropping 556
# cropping 557
# cropping 558
# cropping 559
# cropping 560
# cropping 561
# cropping 562
# cropping 563
# cropping 564
# cropping 565
# cropping 566
# cropping 567
# cropping 568
# cropping 569
# cropping 570
# cropping 571
# cropping 572
# cropping 573
# cropping 574
# cropping 575
# cropping 576
# cropping 577
# cropping 578
# cropping 579
# cropping 580
# cropping 581
# cropping 582
# cropping 583
# cropping 584
# cropping 585
# cropping 586
# cropping 587
# cropping 588
# cropping 589
# cropping 590
# cropping 591
# cropping 592
# cropping 593
# cropping 594
# cropping 595
# cropping 596
# cropping 597
# cropping 598
# cropping 599
# Crops generator: 13
# cropping 600
# Feature generator: 12, 398 sec/image.
# cropping 601
# cropping 602
# cropping 603
# cropping 604
# cropping 605
# cropping 606
# cropping 607
# cropping 608
# cropping 609
# cropping 610
# cropping 611
# cropping 612
# cropping 613
# cropping 614
# cropping 615
# cropping 616
# cropping 617
# cropping 618
# cropping 619
# cropping 620
# cropping 621
# cropping 622
# cropping 623
# cropping 624
# cropping 625
# cropping 626
# cropping 627
# cropping 628
# cropping 629
# cropping 630
# cropping 631
# cropping 632
# cropping 633
# cropping 634
# cropping 635
# cropping 636
# cropping 637
# cropping 638
# cropping 639
# cropping 640
# cropping 641
# cropping 642
# cropping 643
# cropping 644
# cropping 645
# cropping 646
# cropping 647
# cropping 648
# cropping 649
# Crops generator: 14
# cropping 650
# Feature generator: 13, 397 sec/image.
# cropping 651
# cropping 652
# cropping 653
# cropping 654
# cropping 655
# cropping 656
# cropping 657
# cropping 658
# cropping 659
# cropping 660
# cropping 661
# cropping 662
# cropping 663
# cropping 664
# cropping 665
# cropping 666
# cropping 667
# cropping 668
# cropping 669
# cropping 670
# cropping 671
# cropping 672
# cropping 673
# cropping 674
# cropping 675
# cropping 676
# cropping 677
# cropping 678
# cropping 679
# cropping 680
# cropping 681
# cropping 682
# cropping 683
# cropping 684
# cropping 685
# cropping 686
# cropping 687
# cropping 688
# cropping 689
# cropping 690
# cropping 691
# cropping 692
# cropping 693
# cropping 694
# cropping 695
# cropping 696
# cropping 697
# cropping 698
# cropping 699
# Crops generator: 15
# cropping 700
# Feature generator: 14, 397 sec/image.
# cropping 701
# cropping 702
# cropping 703
# cropping 704
# cropping 705
# cropping 706
# cropping 707
# cropping 708
# cropping 709
# cropping 710
# cropping 711
# cropping 712
# cropping 713
# cropping 714
# cropping 715
# cropping 716
# cropping 717
# cropping 718
# cropping 719
# cropping 720
# cropping 721
# cropping 722
# cropping 723
# cropping 724
# cropping 725
# cropping 726
# cropping 727
# cropping 728
# cropping 729
# cropping 730
# cropping 731
# cropping 732
# cropping 733
# cropping 734
# cropping 735
# cropping 736
# cropping 737
# cropping 738
# cropping 739
# cropping 740
# cropping 741
# cropping 742
# cropping 743
# cropping 744
# cropping 745
# cropping 746
# cropping 747
# cropping 748
# cropping 749
# Crops generator: 16
# cropping 750
# Feature generator: 15, 397 sec/image.
# cropping 751
# cropping 752
# cropping 753
# cropping 754
# cropping 755
# cropping 756
# cropping 757
# cropping 758
# cropping 759
# cropping 760
# cropping 761
# cropping 762
# cropping 763
# cropping 764
# cropping 765
# cropping 766
# cropping 767
# cropping 768
# cropping 769
# cropping 770
# cropping 771
# cropping 772
# cropping 773
# cropping 774
# cropping 775
# cropping 776
# cropping 777
# cropping 778
# cropping 779
# cropping 780
# cropping 781
# cropping 782
# cropping 783
# cropping 784
# cropping 785
# cropping 786
# cropping 787
# cropping 788
# cropping 789
# cropping 790
# cropping 791
# cropping 792
# cropping 793
# cropping 794
# cropping 795
# cropping 796
# cropping 797
# cropping 798
# cropping 799
# Crops generator: 17
# cropping 800
# Feature generator: 16, 396 sec/image.
# cropping 801
# cropping 802
# cropping 803
# cropping 804
# cropping 805
# cropping 806
# cropping 807
# cropping 808
# cropping 809
# cropping 810
# cropping 811
# cropping 812
# cropping 813
# cropping 814
# cropping 815
# cropping 816
# cropping 817
# cropping 818
# cropping 819
# cropping 820
# cropping 821
# cropping 822
# cropping 823
# cropping 824
# cropping 825
# cropping 826
# cropping 827
# cropping 828
# cropping 829
# cropping 830
# cropping 831
# cropping 832
# cropping 833
# cropping 834
# cropping 835
# cropping 836
# cropping 837
# cropping 838
# cropping 839
# cropping 840
# cropping 841
# cropping 842
# cropping 843
# cropping 844
# cropping 845
# cropping 846
# cropping 847
# cropping 848
# cropping 849
# Crops generator: 18
# cropping 850
# Feature generator: 17, 396 sec/image.
# cropping 851
# cropping 852
# cropping 853
# cropping 854
# cropping 855
# cropping 856
# cropping 857
# cropping 858
# cropping 859
# cropping 860
# cropping 861
# cropping 862
# cropping 863
# cropping 864
# cropping 865
# cropping 866
# cropping 867
# cropping 868
# cropping 869
# cropping 870
# cropping 871
# cropping 872
# cropping 873
# cropping 874
# cropping 875
# cropping 876
# cropping 877
# cropping 878
# cropping 879
# cropping 880
# cropping 881
# cropping 882
# cropping 883
# cropping 884
# cropping 885
# cropping 886
# cropping 887
# cropping 888
# cropping 889
# cropping 890
# cropping 891
# cropping 892
# cropping 893
# cropping 894
# cropping 895
# cropping 896
# cropping 897
# cropping 898
# cropping 899
# Crops generator: 19
# cropping 900
# Feature generator: 18, 396 sec/image.
# cropping 901
# cropping 902
# cropping 903
# cropping 904
# cropping 905
# cropping 906
# cropping 907
# cropping 908
# cropping 909
# cropping 910
# cropping 911
# cropping 912
# cropping 913
# cropping 914
# cropping 915
# cropping 916
# cropping 917
# cropping 918
# cropping 919
# cropping 920
# cropping 921
# cropping 922
# cropping 923
# cropping 924
# cropping 925
# cropping 926
# cropping 927
# cropping 928
# cropping 929
# cropping 930
# cropping 931
# cropping 932
# cropping 933
# cropping 934
# cropping 935
# cropping 936
# cropping 937
# cropping 938
# cropping 939
# cropping 940
# cropping 941
# cropping 942
# cropping 943
# cropping 944
# cropping 945
# cropping 946
# cropping 947
# cropping 948
# cropping 949
# Crops generator: 20
# cropping 950
# Feature generator: 19, 396 sec/image.
# cropping 951
# cropping 952
# cropping 953
# cropping 954
# cropping 955
# cropping 956
# cropping 957
# cropping 958
# cropping 959
# cropping 960
# cropping 961
# cropping 962
# cropping 963
# cropping 964
# cropping 965
# cropping 966
# cropping 967
# cropping 968
# cropping 969
# cropping 970
# cropping 971
# cropping 972
# cropping 973
# cropping 974
# cropping 975
# cropping 976
# cropping 977
# cropping 978
# cropping 979
# cropping 980
# cropping 981
# cropping 982
# cropping 983
# cropping 984
# cropping 985
# cropping 986
# cropping 987
# cropping 988
# cropping 989
# cropping 990
# cropping 991
# cropping 992
# cropping 993
# cropping 994
# cropping 995
# cropping 996
# cropping 997
# cropping 998
# cropping 999
# Crops generator: 21
# cropping 1000
# Feature generator: 20, 397 sec/image.
# cropping 1001
# cropping 1002
# cropping 1003
# cropping 1004
# cropping 1005
# cropping 1006
# cropping 1007
# cropping 1008
# cropping 1009
# cropping 1010
# cropping 1011
# cropping 1012
# cropping 1013
# cropping 1014
# cropping 1015
# cropping 1016
# cropping 1017
# cropping 1018
# cropping 1019
# cropping 1020
# cropping 1021
# cropping 1022
# cropping 1023
# cropping 1024
# cropping 1025
# cropping 1026
# cropping 1027
# cropping 1028
# cropping 1029
# cropping 1030
# cropping 1031
# cropping 1032
# cropping 1033
# cropping 1034
# cropping 1035
# cropping 1036
# cropping 1037
# cropping 1038
# cropping 1039
# cropping 1040
# cropping 1041
# cropping 1042
# cropping 1043
# cropping 1044
# cropping 1045
# cropping 1046
# cropping 1047
# cropping 1048
# cropping 1049
# Crops generator: 22
# cropping 1050
# Feature generator: 21, 396 sec/image.
# cropping 1051
# cropping 1052
# cropping 1053
# cropping 1054
# cropping 1055
# cropping 1056
# cropping 1057
# cropping 1058
# cropping 1059
# cropping 1060
# cropping 1061
# cropping 1062
# cropping 1063
# cropping 1064
# cropping 1065
# cropping 1066
# cropping 1067
# cropping 1068
# cropping 1069
# cropping 1070
# cropping 1071
# cropping 1072
# cropping 1073
# cropping 1074
# cropping 1075
# cropping 1076
# cropping 1077
# cropping 1078
# cropping 1079
# cropping 1080
# cropping 1081
# cropping 1082
# cropping 1083
# cropping 1084
# cropping 1085
# cropping 1086
# cropping 1087
# cropping 1088
# cropping 1089
# cropping 1090
# cropping 1091
# cropping 1092
# cropping 1093
# cropping 1094
# cropping 1095
# cropping 1096
# cropping 1097
# cropping 1098
# cropping 1099
# Crops generator: 23
# cropping 1100
# Feature generator: 22, 396 sec/image.
# cropping 1101
# cropping 1102
# cropping 1103
# cropping 1104
# cropping 1105
# cropping 1106
# cropping 1107
# cropping 1108
# cropping 1109
# cropping 1110
# cropping 1111
# cropping 1112
# cropping 1113
# cropping 1114
# cropping 1115
# cropping 1116
# cropping 1117
# cropping 1118
# cropping 1119
# cropping 1120
# cropping 1121
# cropping 1122
# cropping 1123
# cropping 1124
# cropping 1125
# cropping 1126
# cropping 1127
# cropping 1128
# cropping 1129
# cropping 1130
# cropping 1131
# cropping 1132
# cropping 1133
# cropping 1134
# cropping 1135
# cropping 1136
# cropping 1137
# cropping 1138
# cropping 1139
# cropping 1140
# cropping 1141
# cropping 1142
# cropping 1143
# cropping 1144
# cropping 1145
# cropping 1146
# cropping 1147
# cropping 1148
# cropping 1149
# Crops generator: 24
# cropping 1150
# Feature generator: 23, 396 sec/image.
# cropping 1151
# cropping 1152
# cropping 1153
# cropping 1154
# cropping 1155
# cropping 1156
# cropping 1157
# cropping 1158
# cropping 1159
# cropping 1160
# cropping 1161
# cropping 1162
# cropping 1163
# cropping 1164
# cropping 1165
# cropping 1166
# cropping 1167
# cropping 1168
# cropping 1169
# cropping 1170
# cropping 1171
# cropping 1172
# cropping 1173
# cropping 1174
# cropping 1175
# cropping 1176
# cropping 1177
# cropping 1178
# cropping 1179
# cropping 1180
# cropping 1181
# cropping 1182
# cropping 1183
# cropping 1184
# cropping 1185
# cropping 1186
# cropping 1187
# cropping 1188
# cropping 1189
# cropping 1190
# cropping 1191
# cropping 1192
# cropping 1193
# cropping 1194
# cropping 1195
# cropping 1196
# cropping 1197
# cropping 1198
# cropping 1199
# Crops generator: 25
# cropping 1200
# Feature generator: 24, 396 sec/image.
# cropping 1201
# cropping 1202
# cropping 1203
# cropping 1204
# cropping 1205
# cropping 1206
# cropping 1207
# cropping 1208
# cropping 1209
# cropping 1210
# cropping 1211
# cropping 1212
# cropping 1213
# cropping 1214
# cropping 1215
# cropping 1216
# cropping 1217
# cropping 1218
# cropping 1219
# cropping 1220
# cropping 1221
# cropping 1222
# cropping 1223
# cropping 1224
# cropping 1225
# cropping 1226
# cropping 1227
# cropping 1228
# cropping 1229
# cropping 1230
# cropping 1231
# cropping 1232
# cropping 1233
# cropping 1234
# cropping 1235
# cropping 1236
# cropping 1237
# cropping 1238
# cropping 1239
# cropping 1240
# cropping 1241
# cropping 1242
# cropping 1243
# cropping 1244
# cropping 1245
# cropping 1246
# cropping 1247
# cropping 1248
# cropping 1249
# Crops generator: 26
# cropping 1250
# Feature generator: 25, 395 sec/image.
# cropping 1251
# cropping 1252
# cropping 1253
# cropping 1254
# cropping 1255
# cropping 1256
# cropping 1257
# cropping 1258
# cropping 1259
# cropping 1260
# cropping 1261
# cropping 1262
# cropping 1263
# cropping 1264
# cropping 1265
# cropping 1266
# cropping 1267
# cropping 1268
# cropping 1269
# cropping 1270
# cropping 1271
# cropping 1272
# cropping 1273
# cropping 1274
# cropping 1275
# cropping 1276
# cropping 1277
# cropping 1278
# cropping 1279
# cropping 1280
# cropping 1281
# cropping 1282
# cropping 1283
# cropping 1284
# cropping 1285
# cropping 1286
# cropping 1287
# cropping 1288
# cropping 1289
# cropping 1290
# cropping 1291
# cropping 1292
# cropping 1293
# cropping 1294
# cropping 1295
# cropping 1296
# cropping 1297
# cropping 1298
# cropping 1299
# Crops generator: 27
# cropping 1300
# Feature generator: 26, 395 sec/image.
# cropping 1301
# cropping 1302
# cropping 1303
# cropping 1304
# cropping 1305
# cropping 1306
# cropping 1307
# cropping 1308
# cropping 1309
# cropping 1310
# cropping 1311
# cropping 1312
# cropping 1313
# cropping 1314
# cropping 1315
# cropping 1316
# cropping 1317
# cropping 1318
# cropping 1319
# cropping 1320
# cropping 1321
# cropping 1322
# cropping 1323
# cropping 1324
# cropping 1325
# cropping 1326
# cropping 1327
# cropping 1328
# cropping 1329
# cropping 1330
# cropping 1331
# cropping 1332
# cropping 1333
# cropping 1334
# cropping 1335
# cropping 1336
# cropping 1337
# cropping 1338
# cropping 1339
# cropping 1340
# cropping 1341
# cropping 1342
# cropping 1343
# cropping 1344
# cropping 1345
# cropping 1346
# cropping 1347
# cropping 1348
# cropping 1349
# Crops generator: 28
# cropping 1350
# Feature generator: 27, 395 sec/image.
# cropping 1351
# cropping 1352
# cropping 1353
# cropping 1354
# cropping 1355
# cropping 1356
# cropping 1357
# cropping 1358
# cropping 1359
# cropping 1360
# cropping 1361
# cropping 1362
# cropping 1363
# cropping 1364
# cropping 1365
# cropping 1366
# cropping 1367
# cropping 1368
# cropping 1369
# cropping 1370
# cropping 1371
# cropping 1372
# cropping 1373
# cropping 1374
# cropping 1375
# cropping 1376
# cropping 1377
# cropping 1378
# cropping 1379
# cropping 1380
# cropping 1381
# cropping 1382
# cropping 1383
# cropping 1384
# cropping 1385
# cropping 1386
# cropping 1387
# cropping 1388
# cropping 1389
# cropping 1390
# cropping 1391
# cropping 1392
# cropping 1393
# cropping 1394
# cropping 1395
# cropping 1396
# cropping 1397
# cropping 1398
# cropping 1399
# Crops generator: 29
# cropping 1400
# Feature generator: 28, 395 sec/image.
# cropping 1401
# cropping 1402
# cropping 1403
# cropping 1404
# cropping 1405
# cropping 1406
# cropping 1407
# cropping 1408
# cropping 1409
# cropping 1410
# cropping 1411
# cropping 1412
# cropping 1413
# cropping 1414
# cropping 1415
# cropping 1416
# cropping 1417
# cropping 1418
# cropping 1419
# cropping 1420
# cropping 1421
# cropping 1422
# cropping 1423
# cropping 1424
# cropping 1425
# cropping 1426
# cropping 1427
# cropping 1428
# cropping 1429
# cropping 1430
# cropping 1431
# cropping 1432
# cropping 1433
# cropping 1434
# cropping 1435
# cropping 1436
# cropping 1437
# cropping 1438
# cropping 1439
# cropping 1440
# cropping 1441
# cropping 1442
# cropping 1443
# cropping 1444
# cropping 1445
# cropping 1446
# cropping 1447
# cropping 1448
# cropping 1449
# Crops generator: 30
# cropping 1450
# Feature generator: 29, 394 sec/image.
# cropping 1451
# cropping 1452
# cropping 1453
# cropping 1454
# cropping 1455
# cropping 1456
# cropping 1457
# cropping 1458
# cropping 1459
# cropping 1460
# cropping 1461
# cropping 1462
# cropping 1463
# cropping 1464
# cropping 1465
# cropping 1466
# cropping 1467
# cropping 1468
# cropping 1469
# cropping 1470
# cropping 1471
# cropping 1472
# cropping 1473
# cropping 1474
# cropping 1475
# cropping 1476
# cropping 1477
# cropping 1478
# cropping 1479
# cropping 1480
# cropping 1481
# cropping 1482
# cropping 1483
# cropping 1484
# cropping 1485
# cropping 1486
# cropping 1487
# cropping 1488
# cropping 1489
# cropping 1490
# cropping 1491
# cropping 1492
# cropping 1493
# cropping 1494
# cropping 1495
# cropping 1496
# cropping 1497
# cropping 1498
# cropping 1499
# Crops generator: 31
# E:\Anaconda3\envs\tfdeeplearning\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: overflow encountered in exp
# E:\Anaconda3\envs\tfdeeplearning\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: overflow encountered in multiply
# cropping 1500
# Feature generator: 30, 395 sec/image.
# cropping 1501
# cropping 1502
# cropping 1503
# cropping 1504
# cropping 1505
# cropping 1506
# cropping 1507
# cropping 1508
# cropping 1509
# cropping 1510
# cropping 1511
# cropping 1512
# cropping 1513
# cropping 1514
# cropping 1515
# cropping 1516
# cropping 1517
# cropping 1518
# cropping 1519
# cropping 1520
# cropping 1521
# cropping 1522
# cropping 1523
# cropping 1524
# cropping 1525
# cropping 1526
# cropping 1527
# cropping 1528
# cropping 1529
# cropping 1530
# cropping 1531
# cropping 1532
# cropping 1533
# cropping 1534
# cropping 1535
# cropping 1536
# cropping 1537
# cropping 1538
# cropping 1539
# cropping 1540
# cropping 1541
# cropping 1542
# cropping 1543
# cropping 1544
# cropping 1545
# cropping 1546
# cropping 1547
# cropping 1548
# cropping 1549
# Crops generator: 32
# cropping 1550
# Feature generator: 31, 397 sec/image.
# cropping 1551
# cropping 1552
# cropping 1553
# cropping 1554
# cropping 1555
# cropping 1556
# cropping 1557
# cropping 1558
# cropping 1559
# cropping 1560
# cropping 1561
# cropping 1562
# cropping 1563
# cropping 1564
# cropping 1565
# cropping 1566
# cropping 1567
# cropping 1568
# cropping 1569
# cropping 1570
# cropping 1571
# cropping 1572
# cropping 1573
# cropping 1574
# cropping 1575
# cropping 1576
# cropping 1577
# cropping 1578
# cropping 1579
# cropping 1580
# cropping 1581
# cropping 1582
# cropping 1583
# cropping 1584
# cropping 1585
# cropping 1586
# cropping 1587
# cropping 1588
# cropping 1589
# cropping 1590
# cropping 1591
# cropping 1592
# cropping 1593
# cropping 1594
# cropping 1595
# cropping 1596
# cropping 1597
# cropping 1598
# cropping 1599
# Crops generator: 33
# cropping 1600
# Feature generator: 32, 398 sec/image.
# cropping 1601
# cropping 1602
# cropping 1603
# cropping 1604
# cropping 1605
# cropping 1606
# cropping 1607
# cropping 1608
# cropping 1609
# cropping 1610
# cropping 1611
# cropping 1612
# cropping 1613
# cropping 1614
# cropping 1615
# cropping 1616
# cropping 1617
# cropping 1618
# cropping 1619
# cropping 1620
# cropping 1621
# cropping 1622
# cropping 1623
# cropping 1624
# cropping 1625
# cropping 1626
# cropping 1627
# cropping 1628
# cropping 1629
# cropping 1630
# cropping 1631
# cropping 1632
# cropping 1633
# cropping 1634
# cropping 1635
# cropping 1636
# cropping 1637
# cropping 1638
# cropping 1639
# cropping 1640
# cropping 1641
# cropping 1642
# cropping 1643
# cropping 1644
# cropping 1645
# cropping 1646
# cropping 1647
# cropping 1648
# cropping 1649
# Crops generator: 34
# cropping 1650
# Feature generator: 33, 400 sec/image.
# cropping 1651
# cropping 1652
# cropping 1653
# cropping 1654
# cropping 1655
# cropping 1656
# cropping 1657
# cropping 1658
# cropping 1659
# cropping 1660
# cropping 1661
# cropping 1662
# cropping 1663
# cropping 1664
# cropping 1665
# cropping 1666
# cropping 1667
# cropping 1668
# cropping 1669
# cropping 1670
# cropping 1671
# cropping 1672
# cropping 1673
# cropping 1674
# cropping 1675
# cropping 1676
# cropping 1677
# cropping 1678
# cropping 1679
# cropping 1680
# cropping 1681
# cropping 1682
# cropping 1683
# cropping 1684
# cropping 1685
# cropping 1686
# cropping 1687
# cropping 1688
# cropping 1689
# cropping 1690
# cropping 1691
# cropping 1692
# cropping 1693
# cropping 1694
# cropping 1695
# cropping 1696
# cropping 1697
# cropping 1698
# cropping 1699
# Crops generator: 35
# cropping 1700
# Feature generator: 34, 401 sec/image.
# cropping 1701
# cropping 1702
# cropping 1703
# cropping 1704
# cropping 1705
# cropping 1706
# cropping 1707
# cropping 1708
# cropping 1709
# cropping 1710
# cropping 1711
# cropping 1712
# cropping 1713
# cropping 1714
# cropping 1715
# cropping 1716
# cropping 1717
# cropping 1718
# cropping 1719
# cropping 1720
# cropping 1721
# cropping 1722
# cropping 1723
# cropping 1724
# cropping 1725
# cropping 1726
# cropping 1727
# cropping 1728
# cropping 1729
# cropping 1730
# cropping 1731
# cropping 1732
# cropping 1733
# cropping 1734
# cropping 1735
# cropping 1736
# cropping 1737
# cropping 1738
# cropping 1739
# cropping 1740
# cropping 1741
# cropping 1742
# cropping 1743
# cropping 1744
# cropping 1745
# cropping 1746
# cropping 1747
# cropping 1748
# cropping 1749
# Crops generator: 36
# cropping 1750
# Feature generator: 35, 402 sec/image.
# cropping 1751
# cropping 1752
# cropping 1753
# cropping 1754
# cropping 1755
# cropping 1756
# cropping 1757
# cropping 1758
# cropping 1759
# cropping 1760
# cropping 1761
# cropping 1762
# cropping 1763
# cropping 1764
# cropping 1765
# cropping 1766
# cropping 1767
# cropping 1768
# cropping 1769
# cropping 1770
# cropping 1771
# cropping 1772
# cropping 1773
# cropping 1774
# cropping 1775
# cropping 1776
# cropping 1777
# cropping 1778
# cropping 1779
# cropping 1780
# cropping 1781
# cropping 1782
# cropping 1783
# cropping 1784
# cropping 1785
# cropping 1786
# cropping 1787
# cropping 1788
# cropping 1789
# cropping 1790
# cropping 1791
# cropping 1792
# cropping 1793
# cropping 1794
# cropping 1795
# cropping 1796
# cropping 1797
# cropping 1798
# cropping 1799
# Crops generator: 37
# cropping 1800
# Feature generator: 36, 403 sec/image.
# cropping 1801
# cropping 1802
# cropping 1803
# cropping 1804
# cropping 1805
# cropping 1806
# cropping 1807
# cropping 1808
# cropping 1809
# cropping 1810
# cropping 1811
# cropping 1812
# cropping 1813
# cropping 1814
# cropping 1815
# cropping 1816
# cropping 1817
# cropping 1818
# cropping 1819
# cropping 1820
# cropping 1821
# cropping 1822
# cropping 1823
# cropping 1824
# cropping 1825
# cropping 1826
# cropping 1827
# cropping 1828
# cropping 1829
# cropping 1830
# cropping 1831
# cropping 1832
# cropping 1833
# cropping 1834
# cropping 1835
# cropping 1836
# cropping 1837
# cropping 1838
# cropping 1839
# cropping 1840
# cropping 1841
# cropping 1842
# cropping 1843
# cropping 1844
# cropping 1845
# cropping 1846
# cropping 1847
# cropping 1848
# cropping 1849
# Crops generator: 38
# cropping 1850
# Feature generator: 37, 404 sec/image.
# cropping 1851
# cropping 1852
# cropping 1853
# cropping 1854
# cropping 1855
# cropping 1856
# cropping 1857
# cropping 1858
# cropping 1859
# cropping 1860
# cropping 1861
# cropping 1862
# cropping 1863
# cropping 1864
# cropping 1865
# cropping 1866
# cropping 1867
# cropping 1868
# cropping 1869
# cropping 1870
# cropping 1871
# cropping 1872
# cropping 1873
# cropping 1874
# cropping 1875
# cropping 1876
# cropping 1877
# cropping 1878
# cropping 1879
# cropping 1880
# cropping 1881
# cropping 1882
# cropping 1883
# cropping 1884
# cropping 1885
# cropping 1886
# cropping 1887
# cropping 1888
# cropping 1889
# cropping 1890
# cropping 1891
# cropping 1892
# cropping 1893
# cropping 1894
# cropping 1895
# cropping 1896
# cropping 1897
# cropping 1898
# cropping 1899
# Crops generator: 39
# cropping 1900
# Feature generator: 38, 405 sec/image.
# cropping 1901
# cropping 1902
# cropping 1903
# cropping 1904
# cropping 1905
# cropping 1906
# cropping 1907
# cropping 1908
# cropping 1909
# cropping 1910
# cropping 1911
# cropping 1912
# cropping 1913
# cropping 1914
# cropping 1915
# cropping 1916
# cropping 1917
# cropping 1918
# cropping 1919
# cropping 1920
# cropping 1921
# cropping 1922
# cropping 1923
# cropping 1924
# cropping 1925
# cropping 1926
# cropping 1927
# cropping 1928
# cropping 1929
# cropping 1930
# cropping 1931
# cropping 1932
# cropping 1933
# cropping 1934
# cropping 1935
# cropping 1936
# cropping 1937
# cropping 1938
# cropping 1939
# cropping 1940
# cropping 1941
# cropping 1942
# cropping 1943
# cropping 1944
# cropping 1945
# cropping 1946
# cropping 1947
# cropping 1948
# cropping 1949
# Crops generator: 40
# cropping 1950
# Feature generator: 39, 406 sec/image.
# cropping 1951
# cropping 1952
# cropping 1953
# cropping 1954
# cropping 1955
# cropping 1956
# cropping 1957
# cropping 1958
# cropping 1959
# cropping 1960
# cropping 1961
# cropping 1962
# cropping 1963
# cropping 1964
# cropping 1965
# cropping 1966
# cropping 1967
# cropping 1968
# cropping 1969
# cropping 1970
# cropping 1971
# cropping 1972
# cropping 1973
# cropping 1974
# cropping 1975
# cropping 1976
# cropping 1977
# cropping 1978
# cropping 1979
# cropping 1980
# cropping 1981
# cropping 1982
# cropping 1983
# cropping 1984
# cropping 1985
# cropping 1986
# cropping 1987
# cropping 1988
# cropping 1989
# cropping 1990
# cropping 1991
# cropping 1992
# cropping 1993
# cropping 1994
# cropping 1995
# cropping 1996
# cropping 1997
# cropping 1998
# cropping 1999
# Crops generator: 41
# cropping 2000
# Feature generator: 40, 407 sec/image.
# cropping 2001
# cropping 2002
# cropping 2003
# cropping 2004
# cropping 2005
# cropping 2006
# cropping 2007
# cropping 2008
# cropping 2009
# cropping 2010
# cropping 2011
# cropping 2012
# cropping 2013
# cropping 2014
# cropping 2015
# cropping 2016
# cropping 2017
# cropping 2018
# cropping 2019
# cropping 2020
# cropping 2021
# cropping 2022
# cropping 2023
# cropping 2024
# cropping 2025
# cropping 2026
# cropping 2027
# cropping 2028
# cropping 2029
# cropping 2030
# cropping 2031
# cropping 2032
# cropping 2033
# cropping 2034
# cropping 2035
# cropping 2036
# cropping 2037
# cropping 2038
# cropping 2039
# cropping 2040
# cropping 2041
# cropping 2042
# cropping 2043
# cropping 2044
# cropping 2045
# cropping 2046
# cropping 2047
# cropping 2048
# cropping 2049
# Crops generator: 42
# cropping 2050
# Feature generator: 41, 408 sec/image.
# cropping 2051
# cropping 2052
# cropping 2053
# cropping 2054
# cropping 2055
# cropping 2056
# cropping 2057
# cropping 2058
# cropping 2059
# cropping 2060
# cropping 2061
# cropping 2062
# cropping 2063
# cropping 2064
# cropping 2065
# cropping 2066
# cropping 2067
# cropping 2068
# cropping 2069
# cropping 2070
# cropping 2071
# cropping 2072
# cropping 2073
# cropping 2074
# cropping 2075
# cropping 2076
# cropping 2077
# cropping 2078
# cropping 2079
# cropping 2080
# cropping 2081
# cropping 2082
# cropping 2083
# cropping 2084
# cropping 2085
# cropping 2086
# cropping 2087
# cropping 2088
# cropping 2089
# cropping 2090
# cropping 2091
# cropping 2092
# cropping 2093
# cropping 2094
# cropping 2095
# cropping 2096
# cropping 2097
# cropping 2098
# cropping 2099
# Crops generator: 43
# cropping 2100
# Feature generator: 42, 408 sec/image.
# cropping 2101
# cropping 2102
# cropping 2103
# cropping 2104
# cropping 2105
# cropping 2106
# cropping 2107
# cropping 2108
# cropping 2109
# cropping 2110
# cropping 2111
# cropping 2112
# cropping 2113
# cropping 2114
# cropping 2115
# cropping 2116
# cropping 2117
# cropping 2118
# cropping 2119
# cropping 2120
# cropping 2121
# cropping 2122
# cropping 2123
# cropping 2124
# cropping 2125
# cropping 2126
# cropping 2127
# cropping 2128
# cropping 2129
# cropping 2130
# cropping 2131
# cropping 2132
# cropping 2133
# cropping 2134
# cropping 2135
# cropping 2136
# cropping 2137
# cropping 2138
# cropping 2139
# cropping 2140
# cropping 2141
# cropping 2142
# cropping 2143
# cropping 2144
# cropping 2145
# cropping 2146
# cropping 2147
# cropping 2148
# cropping 2149
# Crops generator: 44
# cropping 2150
# Feature generator: 43, 407 sec/image.
# cropping 2151
# cropping 2152
# cropping 2153
# cropping 2154
# cropping 2155
# cropping 2156
# cropping 2157
# cropping 2158
# cropping 2159
# cropping 2160
# cropping 2161
# cropping 2162
# cropping 2163
# cropping 2164
# cropping 2165
# cropping 2166
# cropping 2167
# cropping 2168
# cropping 2169
# cropping 2170
# cropping 2171
# cropping 2172
# cropping 2173
# cropping 2174
# cropping 2175
# cropping 2176
# cropping 2177
# cropping 2178
# cropping 2179
# cropping 2180
# cropping 2181
# cropping 2182
# cropping 2183
# cropping 2184
# cropping 2185
# cropping 2186
# cropping 2187
# cropping 2188
# cropping 2189
# cropping 2190
# cropping 2191
# cropping 2192
# cropping 2193
# cropping 2194
# cropping 2195
# cropping 2196
# cropping 2197
# cropping 2198
# cropping 2199
# Crops generator: 45
# cropping 2200
# Feature generator: 44, 407 sec/image.
# cropping 2201
# cropping 2202
# cropping 2203
# cropping 2204
# cropping 2205
# cropping 2206
# cropping 2207
# cropping 2208
# cropping 2209
# cropping 2210
# cropping 2211
# cropping 2212
# cropping 2213
# cropping 2214
# cropping 2215
# cropping 2216
# cropping 2217
# cropping 2218
# cropping 2219
# cropping 2220
# cropping 2221
# cropping 2222
# cropping 2223
# cropping 2224
# cropping 2225
# cropping 2226
# cropping 2227
# cropping 2228
# cropping 2229
# cropping 2230
# cropping 2231
# cropping 2232
# cropping 2233
# cropping 2234
# cropping 2235
# cropping 2236
# cropping 2237
# cropping 2238
# cropping 2239
# cropping 2240
# cropping 2241
# cropping 2242
# cropping 2243
# cropping 2244
# cropping 2245
# cropping 2246
# cropping 2247
# cropping 2248
# cropping 2249
# Crops generator: 46
# cropping 2250
# Feature generator: 45, 406 sec/image.
# cropping 2251
# cropping 2252
# cropping 2253
# cropping 2254
# cropping 2255
# cropping 2256
# cropping 2257
# cropping 2258
# cropping 2259
# cropping 2260
# cropping 2261
# cropping 2262
# cropping 2263
# cropping 2264
# cropping 2265
# cropping 2266
# cropping 2267
# cropping 2268
# cropping 2269
# cropping 2270
# cropping 2271
# cropping 2272
# cropping 2273
# cropping 2274
# cropping 2275
# cropping 2276
# cropping 2277
# cropping 2278
# cropping 2279
# cropping 2280
# cropping 2281
# cropping 2282
# cropping 2283
# cropping 2284
# cropping 2285
# cropping 2286
# cropping 2287
# cropping 2288
# cropping 2289
# cropping 2290
# cropping 2291
# cropping 2292
# cropping 2293
# cropping 2294
# cropping 2295
# cropping 2296
# cropping 2297
# cropping 2298
# cropping 2299
# Crops generator: 47
# cropping 2300
# Feature generator: 46, 406 sec/image.
# cropping 2301
# cropping 2302
# cropping 2303
# cropping 2304
# cropping 2305
# cropping 2306
# cropping 2307
# cropping 2308
# cropping 2309
# cropping 2310
# cropping 2311
# cropping 2312
# cropping 2313
# cropping 2314
# cropping 2315
# cropping 2316
# cropping 2317
# cropping 2318
# cropping 2319
# cropping 2320
# cropping 2321
# cropping 2322
# cropping 2323
# cropping 2324
# cropping 2325
# cropping 2326
# cropping 2327
# cropping 2328
# cropping 2329
# cropping 2330
# cropping 2331
# cropping 2332
# cropping 2333
# cropping 2334
# cropping 2335
# cropping 2336
# cropping 2337
# cropping 2338
# cropping 2339
# cropping 2340
# cropping 2341
# cropping 2342
# cropping 2343
# cropping 2344
# cropping 2345
# cropping 2346
# cropping 2347
# cropping 2348
# cropping 2349
# Crops generator: 48
# cropping 2350
# Feature generator: 47, 406 sec/image.
# cropping 2351
# cropping 2352
# cropping 2353
# cropping 2354
# cropping 2355
# cropping 2356
# cropping 2357
# cropping 2358
# cropping 2359
# cropping 2360
# cropping 2361
# cropping 2362
# cropping 2363
# cropping 2364
# cropping 2365
# cropping 2366
# cropping 2367
# cropping 2368
# cropping 2369
# cropping 2370
# cropping 2371
# cropping 2372
# cropping 2373
# cropping 2374
# cropping 2375
# cropping 2376
# cropping 2377
# cropping 2378
# cropping 2379
# cropping 2380
# cropping 2381
# cropping 2382
# cropping 2383
# cropping 2384
# cropping 2385
# cropping 2386
# cropping 2387
# cropping 2388
# cropping 2389
# cropping 2390
# cropping 2391
# cropping 2392
# cropping 2393
# cropping 2394
# cropping 2395
# cropping 2396
# cropping 2397
# cropping 2398
# cropping 2399
# Crops generator: 49
# cropping 2400
# Feature generator: 48, 405 sec/image.
# cropping 2401
# cropping 2402
# cropping 2403
# cropping 2404
# cropping 2405
# cropping 2406
# cropping 2407
# cropping 2408
# cropping 2409
# cropping 2410
# cropping 2411
# cropping 2412
# cropping 2413
# cropping 2414
# cropping 2415
# cropping 2416
# cropping 2417
# cropping 2418
# cropping 2419
# cropping 2420
# cropping 2421
# cropping 2422
# cropping 2423
# cropping 2424
# cropping 2425
# cropping 2426
# cropping 2427
# cropping 2428
# cropping 2429
# cropping 2430
# cropping 2431
# cropping 2432
# cropping 2433
# cropping 2434
# cropping 2435
# cropping 2436
# cropping 2437
# cropping 2438
# cropping 2439
# cropping 2440
# cropping 2441
# cropping 2442
# cropping 2443
# cropping 2444
# cropping 2445
# cropping 2446
# cropping 2447
# cropping 2448
# cropping 2449
# Crops generator: 50
# cropping 2450
# Feature generator: 49, 405 sec/image.
# cropping 2451
# cropping 2452
# cropping 2453
# cropping 2454
# cropping 2455
# cropping 2456
# cropping 2457
# cropping 2458
# cropping 2459
# cropping 2460
# cropping 2461
# cropping 2462
# cropping 2463
# cropping 2464
# cropping 2465
# cropping 2466
# cropping 2467
# cropping 2468
# cropping 2469
# cropping 2470
# cropping 2471
# cropping 2472
# cropping 2473
# cropping 2474
# cropping 2475
# cropping 2476
# cropping 2477
# cropping 2478
# cropping 2479
# cropping 2480
# cropping 2481
# cropping 2482
# cropping 2483
# cropping 2484
# cropping 2485
# cropping 2486
# cropping 2487
# cropping 2488
# cropping 2489
# cropping 2490
# cropping 2491
# cropping 2492
# cropping 2493
# cropping 2494
# cropping 2495
# cropping 2496
# cropping 2497
# cropping 2498
# cropping 2499
# Crops generator: 51
# cropping 2500
# Feature generator: 50, 405 sec/image.
# cropping 2501
# cropping 2502
# cropping 2503
# cropping 2504
# cropping 2505
# cropping 2506
# cropping 2507
# cropping 2508
# cropping 2509
# cropping 2510
# cropping 2511
# cropping 2512
# cropping 2513
# cropping 2514
# cropping 2515
# cropping 2516
# cropping 2517
# cropping 2518
# cropping 2519
# cropping 2520
# cropping 2521
# cropping 2522
# cropping 2523
# cropping 2524
# cropping 2525
# cropping 2526
# cropping 2527
# cropping 2528
# cropping 2529
# cropping 2530
# cropping 2531
# cropping 2532
# cropping 2533
# cropping 2534
# cropping 2535
# cropping 2536
# cropping 2537
# cropping 2538
# cropping 2539
# cropping 2540
# cropping 2541
# cropping 2542
# cropping 2543
# cropping 2544
# cropping 2545
# cropping 2546
# cropping 2547
# cropping 2548
# cropping 2549
# Crops generator: 52
# cropping 2550
# Feature generator: 51, 404 sec/image.
# cropping 2551
# cropping 2552
# cropping 2553
# cropping 2554
# cropping 2555
# cropping 2556
# cropping 2557
# cropping 2558
# cropping 2559
# cropping 2560
# cropping 2561
# cropping 2562
# cropping 2563
# cropping 2564
# cropping 2565
# cropping 2566
# cropping 2567
# cropping 2568
# cropping 2569
# cropping 2570
# cropping 2571
# cropping 2572
# cropping 2573
# cropping 2574
# cropping 2575
# cropping 2576
# cropping 2577
# cropping 2578
# cropping 2579
# cropping 2580
# cropping 2581
# cropping 2582
# cropping 2583
# cropping 2584
# cropping 2585
# cropping 2586
# cropping 2587
# cropping 2588
# cropping 2589
# cropping 2590
# cropping 2591
# cropping 2592
# cropping 2593
# cropping 2594
# cropping 2595
# cropping 2596
# cropping 2597
# cropping 2598
# cropping 2599
# Crops generator: 53
# cropping 2600
# Feature generator: 52, 404 sec/image.
# cropping 2601
# cropping 2602
# cropping 2603
# cropping 2604
# cropping 2605
# cropping 2606
# cropping 2607
# cropping 2608
# cropping 2609
# cropping 2610
# cropping 2611
# cropping 2612
# cropping 2613
# cropping 2614
# cropping 2615
# cropping 2616
# cropping 2617
# cropping 2618
# cropping 2619
# cropping 2620
# cropping 2621
# cropping 2622
# cropping 2623
# cropping 2624
# cropping 2625
# cropping 2626
# cropping 2627
# cropping 2628
# cropping 2629
# cropping 2630
# cropping 2631
# cropping 2632
# cropping 2633
# cropping 2634
# cropping 2635
# cropping 2636
# cropping 2637
# cropping 2638
# cropping 2639
# cropping 2640
# cropping 2641
# cropping 2642
# cropping 2643
# cropping 2644
# cropping 2645
# cropping 2646
# cropping 2647
# cropping 2648
# cropping 2649
# Crops generator: 54
# cropping 2650
# Feature generator: 53, 405 sec/image.
# cropping 2651
# cropping 2652
# cropping 2653
# cropping 2654
# cropping 2655
# cropping 2656
# cropping 2657
# cropping 2658
# cropping 2659
# cropping 2660
# cropping 2661
# cropping 2662
# cropping 2663
# cropping 2664
# cropping 2665
# cropping 2666
# cropping 2667
# cropping 2668
# cropping 2669
# cropping 2670
# cropping 2671
# cropping 2672
# cropping 2673
# cropping 2674
# cropping 2675
# cropping 2676
# cropping 2677
# cropping 2678
# cropping 2679
# cropping 2680
# cropping 2681
# cropping 2682
# cropping 2683
# cropping 2684
# cropping 2685
# cropping 2686
# cropping 2687
# cropping 2688
# cropping 2689
# cropping 2690
# cropping 2691
# cropping 2692
# cropping 2693
# cropping 2694
# cropping 2695
# cropping 2696
# cropping 2697
# cropping 2698
# cropping 2699
# Crops generator: 55
# cropping 2700
# Feature generator: 54, 405 sec/image.
# cropping 2701
# cropping 2702
# cropping 2703
# cropping 2704
# cropping 2705
# cropping 2706
# cropping 2707
# cropping 2708
# cropping 2709
# cropping 2710
# cropping 2711
# cropping 2712
# cropping 2713
# cropping 2714
# cropping 2715
# cropping 2716
# cropping 2717
# cropping 2718
# cropping 2719
# cropping 2720
# cropping 2721
# cropping 2722
# cropping 2723
# cropping 2724
# cropping 2725
# cropping 2726
# cropping 2727
# cropping 2728
# cropping 2729
# cropping 2730
# cropping 2731
# cropping 2732
# cropping 2733
# cropping 2734
# cropping 2735
# cropping 2736
# cropping 2737
# cropping 2738
# cropping 2739
# cropping 2740
# cropping 2741
# cropping 2742
# cropping 2743
# cropping 2744
# cropping 2745
# cropping 2746
# cropping 2747
# cropping 2748
# cropping 2749
# Crops generator: 56
# cropping 2750
# Feature generator: 55, 405 sec/image.
# cropping 2751
# cropping 2752
# cropping 2753
# cropping 2754
# cropping 2755
# cropping 2756
# cropping 2757
# cropping 2758
# cropping 2759
# cropping 2760
# cropping 2761
# cropping 2762
# cropping 2763
# cropping 2764
# cropping 2765
# cropping 2766
# cropping 2767
# cropping 2768
# cropping 2769
# cropping 2770
# cropping 2771
# cropping 2772
# cropping 2773
# cropping 2774
# cropping 2775
# cropping 2776
# cropping 2777
# cropping 2778
# cropping 2779
# cropping 2780
# cropping 2781
# cropping 2782
# cropping 2783
# cropping 2784
# cropping 2785
# cropping 2786
# cropping 2787
# cropping 2788
# cropping 2789
# cropping 2790
# cropping 2791
# cropping 2792
# cropping 2793
# cropping 2794
# cropping 2795
# cropping 2796
# cropping 2797
# cropping 2798
# cropping 2799
# Crops generator: 57
# cropping 2800
# Feature generator: 56, 405 sec/image.
# cropping 2801
# cropping 2802
# cropping 2803
# cropping 2804
# cropping 2805
# cropping 2806
# cropping 2807
# cropping 2808
# cropping 2809
# cropping 2810
# cropping 2811
# cropping 2812
# cropping 2813
# cropping 2814
# cropping 2815
# cropping 2816
# cropping 2817
# cropping 2818
# cropping 2819
# cropping 2820
# cropping 2821
# cropping 2822
# cropping 2823
# cropping 2824
# cropping 2825
# cropping 2826
# cropping 2827
# cropping 2828
# cropping 2829
# cropping 2830
# cropping 2831
# cropping 2832
# cropping 2833
# cropping 2834
# cropping 2835
# cropping 2836
# cropping 2837
# cropping 2838
# cropping 2839
# cropping 2840
# cropping 2841
# cropping 2842
# cropping 2843
# cropping 2844
# cropping 2845
# cropping 2846
# cropping 2847
# cropping 2848
# cropping 2849
# Crops generator: 58
# cropping 2850
# Feature generator: 57, 405 sec/image.
# cropping 2851
# cropping 2852
# cropping 2853
# cropping 2854
# cropping 2855
# cropping 2856
# cropping 2857
# cropping 2858
# cropping 2859
# cropping 2860
# cropping 2861
# cropping 2862
# cropping 2863
# cropping 2864
# cropping 2865
# cropping 2866
# cropping 2867
# cropping 2868
# cropping 2869
# cropping 2870
# cropping 2871
# cropping 2872
# cropping 2873
# cropping 2874
# cropping 2875
# cropping 2876
# cropping 2877
# cropping 2878
# cropping 2879
# cropping 2880
# cropping 2881
# cropping 2882
# cropping 2883
# cropping 2884
# cropping 2885
# cropping 2886
# cropping 2887
# cropping 2888
# cropping 2889
# cropping 2890
# cropping 2891
# cropping 2892
# cropping 2893
# cropping 2894
# cropping 2895
# cropping 2896
# cropping 2897
# cropping 2898
# cropping 2899
# Crops generator: 59
# cropping 2900
# Feature generator: 58, 407 sec/image.
# cropping 2901
# cropping 2902
# cropping 2903
# cropping 2904
# cropping 2905
# cropping 2906
# cropping 2907
# cropping 2908
# cropping 2909
# cropping 2910
# cropping 2911
# cropping 2912
# cropping 2913
# cropping 2914
# cropping 2915
# cropping 2916
# cropping 2917
# cropping 2918
# cropping 2919
# cropping 2920
# cropping 2921
# cropping 2922
# cropping 2923
# cropping 2924
# cropping 2925
# cropping 2926
# cropping 2927
# cropping 2928
# cropping 2929
# cropping 2930
# cropping 2931
# cropping 2932
# cropping 2933
# cropping 2934
# cropping 2935
# cropping 2936
# cropping 2937
# cropping 2938
# cropping 2939
# cropping 2940
# cropping 2941
# cropping 2942
# cropping 2943
# cropping 2944
# cropping 2945
# cropping 2946
# cropping 2947
# cropping 2948
# cropping 2949
# Crops generator: 60
# cropping 2950
# Feature generator: 59, 408 sec/image.
# cropping 2951
# cropping 2952
# cropping 2953
# cropping 2954
# cropping 2955
# cropping 2956
# cropping 2957
# cropping 2958
# cropping 2959
# cropping 2960
# cropping 2961
# cropping 2962
# cropping 2963
# cropping 2964
# cropping 2965
# cropping 2966
# cropping 2967
# cropping 2968
# cropping 2969
# cropping 2970
# cropping 2971
# cropping 2972
# cropping 2973
# cropping 2974
# cropping 2975
# cropping 2976
# cropping 2977
# cropping 2978
# cropping 2979
# cropping 2980
# cropping 2981
# cropping 2982
# cropping 2983
# cropping 2984
# cropping 2985
# cropping 2986
# cropping 2987
# cropping 2988
# cropping 2989
# cropping 2990
# cropping 2991
# cropping 2992
# cropping 2993
# cropping 2994
# cropping 2995
# cropping 2996
# cropping 2997
# cropping 2998
# cropping 2999
# Crops generator: 61
# cropping 3000
# Feature generator: 60, 408 sec/image.
# cropping 3001
# cropping 3002
# cropping 3003
# cropping 3004
# cropping 3005
# cropping 3006
# cropping 3007
# cropping 3008
# cropping 3009
# cropping 3010
# cropping 3011
# cropping 3012
# cropping 3013
# cropping 3014
# cropping 3015
# cropping 3016
# cropping 3017
# cropping 3018
# cropping 3019
# cropping 3020
# cropping 3021
# cropping 3022
# cropping 3023
# cropping 3024
# cropping 3025
# cropping 3026
# cropping 3027
# cropping 3028
# cropping 3029
# cropping 3030
# cropping 3031
# cropping 3032
# cropping 3033
# cropping 3034
# cropping 3035
# cropping 3036
# cropping 3037
# cropping 3038
# cropping 3039
# cropping 3040
# cropping 3041
# cropping 3042
# cropping 3043
# cropping 3044
# cropping 3045
# cropping 3046
# cropping 3047
# cropping 3048
# cropping 3049
# Crops generator: 62
# cropping 3050
# Feature generator: 61, 409 sec/image.
# cropping 3051
# cropping 3052
# cropping 3053
# cropping 3054
# cropping 3055
# cropping 3056
# cropping 3057
# cropping 3058
# cropping 3059
# cropping 3060
# cropping 3061
# cropping 3062
# cropping 3063
# cropping 3064
# cropping 3065
# cropping 3066
# cropping 3067
# cropping 3068
# cropping 3069
# cropping 3070
# cropping 3071
# cropping 3072
# cropping 3073
# cropping 3074
# cropping 3075
# cropping 3076
# cropping 3077
# cropping 3078
# cropping 3079
# cropping 3080
# cropping 3081
# cropping 3082
# cropping 3083
# cropping 3084
# cropping 3085
# cropping 3086
# cropping 3087
# cropping 3088
# cropping 3089
# cropping 3090
# cropping 3091
# cropping 3092
# cropping 3093
# cropping 3094
# cropping 3095
# cropping 3096
# cropping 3097
# cropping 3098
# cropping 3099
# Crops generator: 63
# cropping 3100
# Feature generator: 62, 409 sec/image.
# cropping 3101
# cropping 3102
# cropping 3103
# cropping 3104
# cropping 3105
# cropping 3106
# cropping 3107
# cropping 3108
# cropping 3109
# cropping 3110
# cropping 3111
# cropping 3112
# cropping 3113
# cropping 3114
# cropping 3115
# cropping 3116
# cropping 3117
# cropping 3118
# cropping 3119
# cropping 3120
# cropping 3121
# cropping 3122
# cropping 3123
# cropping 3124
# cropping 3125
# cropping 3126
# cropping 3127
# cropping 3128
# cropping 3129
# cropping 3130
# cropping 3131
# cropping 3132
# cropping 3133
# cropping 3134
# cropping 3135
# cropping 3136
# cropping 3137
# cropping 3138
# cropping 3139
# cropping 3140
# cropping 3141
# cropping 3142
# cropping 3143
# cropping 3144
# cropping 3145
# cropping 3146
# cropping 3147
# cropping 3148
# cropping 3149
# Crops generator: 64
# C:\Users\naveen\AppData\Roaming\Python\Python35\site-packages\numpy\lib\function_base.py:356: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\naveen\AppData\Roaming\Python\Python35\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# E:\Anaconda3\envs\tfdeeplearning\lib\site-packages\ipykernel_launcher.py:15: RuntimeWarning: Degrees of freedom <= 0 for slice
#   from ipykernel import kernelapp as app
# C:\Users\naveen\AppData\Roaming\Python\Python35\site-packages\numpy\lib\function_base.py:2326: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\naveen\AppData\Roaming\Python\Python35\site-packages\numpy\lib\function_base.py:2326: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-10-b66688616cf6> in <module>()
#      29                 crops_and_output_file = crops_gen(file_list)
#      30                 #crops_and_output_file_ = threaded_generator(crops_and_output_file, num_cached=NUM_CACHED)
# ---> 31                 features_gen(crops_and_output_file, model)
#
# <ipython-input-2-5cfb8b719f25> in features_gen(crops_and_output_file, model)
#     162     pooled_features = []
#     163     i = 0
# --> 164     for j, (crops, output_file) in enumerate(crops_and_output_file):
#     165         print("cropping",j)
#     166         if current_file is None:
#
# <ipython-input-2-5cfb8b719f25> in crops_gen(file_list)
#     152     for i, (image_file, output_file) in enumerate(file_list):
#     153         print("Crops generator:", i + 1)
# --> 154         for crops in process_image(image_file):
#     155             yield crops, output_file
#     156
#
# <ipython-input-2-5cfb8b719f25> in process_image(image_file)
#     141         img = cv2.resize(img, None, fx=SCALE, fy=SCALE, interpolation=cv2.INTER_CUBIC)
#     142     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# --> 143     img_norm = normalize_staining(img)
#     144
#     145     for _ in range(AUGMENTATIONS_PER_IMAGE):
#
# <ipython-input-2-5cfb8b719f25> in normalize_staining(img)
#      13     OD = -np.log((img.astype("uint16") + 1) / Io)
#      14     ODhat = OD[(OD >= beta).all(axis=1)]
# ---> 15     W, V = np.linalg.eig(np.cov(ODhat, rowvar=False))
#      16
#      17     Vec = -V.T[:2][::-1].T
#
# ~\AppData\Roaming\Python\Python35\site-packages\numpy\linalg\linalg.py in eig(a)
#    1260     _assertRankAtLeast2(a)
#    1261     _assertNdSquareness(a)
# -> 1262     _assertFinite(a)
#    1263     t, result_t = _commonType(a)
#    1264
#
# ~\AppData\Roaming\Python\Python35\site-packages\numpy\linalg\linalg.py in _assertFinite(*arrays)
#     218     for a in arrays:
#     219         if not (isfinite(a).all()):
# --> 220             raise LinAlgError("Array must not contain infs or NaNs")
#     221
#     222 def _isEmpty2d(arr):
#
# LinAlgError: Array must not contain infs or NaNs
